# %%
import numpy as np
import pandas as pd

LINUX_DIRECTORY = "/home/u20482jg/MPHYS_Project_Local"

reg_data = np.genfromtxt(f"{LINUX_DIRECTORY}/data/CORNISH_UCHII_Catalogue.reg", delimiter=" ", dtype = 'str')
